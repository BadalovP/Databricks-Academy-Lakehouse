-- %%
-- Purpose:
-- Return the latest numeric pipeline status for the Databricks SQL Alert.
--
-- Alert condition:
-- FIRST_ROW(alert_value) > 0

SELECT
    alert_value,
    overall_status,
    integrity_status,
    alert_message,
    latest_validation_at
FROM
    dbr_dev.parvinbadalov.olist_pipeline_alert_status;
