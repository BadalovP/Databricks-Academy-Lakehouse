# %%
# %sql
DROP TABLE IF EXISTS dbr_dev.parvinbadalov_bronze.orders_autoloader;
DROP TABLE IF EXISTS dbr_dev.parvinbadalov_bronze.orders_copy_into;

# %%
dbutils.fs.rm(
    "abfss://parvinbadalov@dlspl21databricks.dfs.core.windows.net/checkpoints/orders_autoloader/",
    recurse=True
)

# %%
print("cluster ok")
