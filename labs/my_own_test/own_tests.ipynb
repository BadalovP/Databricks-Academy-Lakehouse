# %%
# %sql
ALTER TABLE dbr_dev.parvinbadalov_lab06_ext.fact_encounters
DROP ROW FILTER;

# %%
# %sql
ALTER TABLE dbr_dev.parvinbadalov_lab06_ext.dim_patient
ALTER COLUMN ssn DROP MASK;

ALTER TABLE dbr_dev.parvinbadalov_lab06_ext.dim_patient
ALTER COLUMN first_name DROP MASK;

ALTER TABLE dbr_dev.parvinbadalov_lab06_ext.dim_patient
ALTER COLUMN last_name DROP MASK;

ALTER TABLE dbr_dev.parvinbadalov_lab06_ext.dim_patient
ALTER COLUMN address DROP MASK;
