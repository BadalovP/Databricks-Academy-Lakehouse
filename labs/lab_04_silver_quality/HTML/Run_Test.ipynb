# %% [markdown]
# # Lab 04 — Unit Test Runner
#
# This notebook runs the reusable Lab 4 Python unit tests.
#
# It is **not part of the production data pipeline** and should not be added to the main Lab 4 Job DAG.
#
# Use it:
# - manually during development;
# - before deployment;
# - or from a separate CI/test workflow.
#
# Expected repository files:
#
# ```text
# lab_04_silver_quality/
# ├── src/
# │   ├── quality_rules.py
# │   └── merge_utils.py
# └── tests/
#     ├── test_quality_rules.py
#     └── test_merge_idempotency.py
# ```

# %%
# %pip install -q pytest
# Out:
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
import os
import sys
from pathlib import Path

import pytest

lab04_root = Path(
    "/Workspace/Users/parvinbadalov@yahoo.com/"
    "Databricks-Academy-Lakehouse/labs/lab_04_silver_quality"
)

required_test_files = [
    lab04_root / "tests" / "test_quality_rules.py",
    lab04_root / "tests" / "test_merge_idempotency.py",
]

missing_test_files = [
    str(path)
    for path in required_test_files
    if not path.exists()
]

if missing_test_files:
    raise FileNotFoundError(
        "Required Lab 4 unit-test files are missing:\n- "
        + "\n- ".join(missing_test_files)
    )

os.chdir(lab04_root)

lab04_root_str = str(lab04_root)
if lab04_root_str not in sys.path:
    sys.path.insert(0, lab04_root_str)

sys.dont_write_bytecode = True

# Databricks can retain imported modules in the Python process.
# Remove cached helper modules so pytest loads the latest saved code.
for module_name in [
    "src",
    "src.quality_rules",
    "src.merge_utils",
]:
    sys.modules.pop(module_name, None)

result = pytest.main(
    [
        "-v",
        "--tb=short",
        "--assert=plain",
        "-p",
        "no:cacheprovider",
        "tests/test_quality_rules.py",
        "tests/test_merge_idempotency.py",
        "tests/test_contracts.py",
    ]
)

if result != pytest.ExitCode.OK:
    raise AssertionError(
        f"Lab 4 tests failed with pytest exit code {result}."
    )

print("✅ All Lab 4 reusable-module unit tests passed.")
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.3, pytest-8.3.5, pluggy-1.5.0 -- /local_disk0/.ephemeral_nfs/envs/pythonEnv-cbf617ac-ebeb-4a49-8f55-52f3a42c59c8/bin/python
# rootdir: /Workspace/Users/parvinbadalov@yahoo.com/Databricks-Academy-Lakehouse/labs/lab_04_silver_quality
# plugins: langsmith-0.6.1, anyio-4.7.0
# collecting ... collected 22 items
#
# tests/test_quality_rules.py::test_valid_row_passes_all_rules PASSED      [  4%]
# tests/test_quality_rules.py::test_invalid_row_records_every_failure_reason PASSED [  9%]
# tests/test_quality_rules.py::test_duplicate_business_row_is_quarantined PASSED [ 13%]
# tests/test_quality_rules.py::test_split_and_metrics_reconcile PASSED     [ 18%]
# tests/test_quality_rules.py::test_rule_failure_summary_counts_failures PASSED [ 22%]
# tests/test_quality_rules.py::test_missing_required_column_raises_clear_error PASSED [ 27%]
# tests/test_quality_rules.py::test_split_requires_quality_metadata PASSED [ 31%]
# tests/test_merge_idempotency.py::test_add_record_hash_is_deterministic PASSED [ 36%]
# tests/test_merge_idempotency.py::test_record_hash_changes_with_tracked_value PASSED [ 40%]
# tests/test_merge_idempotency.py::test_deduplicate_latest_keeps_newest_record PASSED [ 45%]
# tests/test_merge_idempotency.py::test_classify_merge_actions PASSED      [ 50%]
# tests/test_merge_idempotency.py::test_merge_upsert_applies_expected_changes PASSED [ 54%]
# tests/test_merge_idempotency.py::test_merge_replay_is_idempotent PASSED  [ 59%]
# tests/test_contracts.py::test_contract_v1_loads PASSED                   [ 63%]
# tests/test_contracts.py::test_contract_v2_loads PASSED                   [ 68%]
# tests/test_contracts.py::test_v1_has_eight_source_columns PASSED         [ 72%]
# tests/test_contracts.py::test_v2_has_ten_columns PASSED                  [ 77%]
# tests/test_contracts.py::test_v2_supersedes_v1 PASSED                    [ 81%]
# tests/test_contracts.py::test_v2_adds_only_approved_columns PASSED       [ 86%]
# tests/test_contracts.py::test_quantity_is_widened PASSED                 [ 90%]
# tests/test_contracts.py::test_v2_allowed_loyalty_values PASSED           [ 95%]
# tests/test_contracts.py::test_v2_allowed_sales_channels PASSED           [100%]
#
# ============================= 22 passed in 41.18s ==============================
# ✅ All Lab 4 reusable-module unit tests passed.
